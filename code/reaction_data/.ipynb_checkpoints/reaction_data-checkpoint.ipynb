# %%
# Plotting 
#%pip install svgutils

import numpy as np
import os
from rdkit import Chem
from rdkit.Chem import rdChemReactions
from rdkit.Chem import Draw
from rdkit.Chem import AllChem
from rdkit.Chem.Draw import IPythonConsole #Needed to show molecules
from rdkit.Chem.Draw.MolDrawing import MolDrawing, DrawingOptions #Only needed if modifying defaults
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import rdDepictor
from rdkit.Chem.Draw import rdMolDraw2D
from IPython.display import SVG

import torch
import torch.nn.functional as F

files = {e.split("-")[1].split(".")[0]: os.getenv("HOME")+"/data/USTPO/" 
         + e for e in os.listdir(os.getenv("HOME")+"/data/USTPO/")}
with open(files["valid"]) as f:
    lines = f.readlines()
lines = [line[:-1] for line in lines]


for i in range(30):
    rxn = rdChemReactions.ReactionFromSmarts
    reaction = rxn(lines[i])
    rs = list(reaction.GetReactants())
    ps = list(reaction.GetProducts())
    title = ""
    for r in rs:
        title += Chem.MolToSmiles(r) + "."

    title = title[:-1] + ">>"
    for p in ps:
        title += Chem.MolToSmiles(r) + "."
    title = title[:-1]

    d = Draw.MolDraw2DSVG(900, 400)
    opts = d.drawOptions()        
    opts.bgColor = None
    opts.clearBackground = False
    opts.bondLineWidth = 1
    d.DrawReaction(reaction)
    d.FinishDrawing()



    svg = d.GetDrawingText()
    s = svg.replace('svg:','')

    import svgutils.transform as sg
    fig = sg.fromstring(s)
    label = sg.TextElement(450-len(lines[i])*3.2, 80, lines[i], size=11, 
                           font='sans-serif', anchor='bottom', color='#000000')
    fig.append(label)
    display(SVG(fig.to_str()))

# %%
# Parsing
# Plotting 
#%pip install svgutils

import numpy as np
import os
from rdkit import Chem
from rdkit.Chem import rdChemReactions
from rdkit.Chem import Draw
from rdkit.Chem import AllChem
from rdkit.Chem.Draw import IPythonConsole #Needed to show molecules
from rdkit.Chem.Draw.MolDrawing import MolDrawing, DrawingOptions #Only needed if modifying defaults
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import rdDepictor
from rdkit.Chem.Draw import rdMolDraw2D
from IPython.display import SVG
import pickle

import torch
import torch.nn.functional as F
import time


#phase = "valid"
for phase in ["train", "valid", "test"]:
    files = {e.split("-")[1].split(".")[0]: os.getenv("HOME")+"/data/USTPO/" 
             + e for e in os.listdir(os.getenv("HOME")+"/data/USTPO/")}
    with open(files[phase]) as f:
        lines = f.readlines()
    lines = [line[:-1] for line in lines]


    chars = " ^#%()+-./0123456789=@ABCDEFGHIKLMNOPRSTVXYZ[\\]abcdefgilmnoprstuy$"
    char_to_ix = { ch:i for i,ch in enumerate(chars) }
    ix_to_char = { i:ch for i,ch in enumerate(chars) }
    max_len = 160
    vacant = " "*max_len

    lines_out = []
    lines_out_ = []
    for line in lines:
        rs_, ps_ = line.split(" >> ")
        if max(len(rs_),len(ps_)) > max_len: continue
        rs_, ps_ = rs_+vacant[len(rs_):], ps_+vacant[len(ps_):]
        rs, ps = torch.zeros(max_len),torch.zeros(max_len)
        for i in range(max_len): rs[i], ps[i] = char_to_ix[rs_[i]], char_to_ix[ps_[i]]
        lines_out.append({"rs": rs, "ps": ps})
        lines_out_.append({"rs": rs_, "ps": ps_})
        #print(rs_)
        #print(rs)
        #rs = F.one_hot(rs.to(dtype=torch.int64), num_classes=len(chars))
        #print(rs)
        #print(torch.argmax(rs, axis=1))
    
    print("finished parsing " + phase)

    with open("/home/arvid/data/USTPO_text/"+ phase +".pickle", 'wb') as handle:
        pickle.dump(lines_out_, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# finished parsing train
# finished parsing valid
# finished parsing test

# %%
import pickle
data = {}
for phase in ["train", "valid", "test"]:
    with open("/home/arvid/data/USTPO_text/" + phase + ".pickle", 'rb') as handle:
        data[phase] = pickle.load(handle)

# %%
data
# Out:
# {'train': [{'rs': 'O=C1CC[C@H](CN2CCN(CCOc3cc4ncnc(Nc5ccc(F)c(Cl)c5)c4cc3OC3CCCC3)CC2)O1                                                                                           ',
#    'ps': 'CS(=O)(=O)OC[C@H]1CCC(=O)O1.Fc1ccc(Nc2ncnc3cc(OCCN4CCNCC4)c(OC4CCCC4)cc23)cc1Cl                                                                                 '},
#   {'rs': 'Nc1nc2[nH]c(CCCc3csc(C(=O)O)c3)cc2c(=O)[nH]1                                                                                                                    ',
#    'ps': 'COC(=O)c1cc(CCCc2cc3c(=O)[nH]c(N)nc3[nH]2)cs1                                                                                                                   '},
#   {'rs': 'CC1(C)OB(c2cccc(Nc3nccc(C(F)(F)F)n3)c2)OC1(C)C                                                                                                                  ',
#    'ps': 'CC1(C)OB(B2OC(C)(C)C(C)(C)O2)OC1(C)C.FC(F)(F)c1ccnc(Nc2cccc(Br)c2)n1                                                                                            '},
#   {'rs': 'CC(C)(C)OC(=O)NCC(=O)CCC(=O)OCCCC(=O)O                                                                                                                          ',
#    'ps': 'CC(C)(C)OC(=O)NCC(=O)CCC(=O)OCCCC(=O)OCc1ccccc1                                                                                                                 '},
#   {'rs': 'Fc1cc2c(NC3CCCCCC3)ncnc2cn1                                                                                                                                     ',
#    'ps': 'Fc1cc2c(Cl)ncnc2cn1.NC1CCCCCC1                                                                                                                                  '},
#   {'rs': 'COc1ccc(S(=O)(=O)Nc2ccc3c(c2)B(O)OC3)c([N+](=O)[O-])c1                                                                                                          ',
#    'ps': 'COc1ccc(S(=O)(=O)Cl)c([N+](=O)[O-])c1.Nc1ccc2c(c1)B(O)OC2                                                                                                       '},
#   {'rs': 'O=C(NS(=O)(=O)C1CC1)c1cc(C2CC2)c(OCC2CCN(S(=O)(=O)c3cc(Cl)c(Br)cc3F)CC2)cc1F                                                                                    ',
#    'ps': 'NS(=O)(=O)C1CC1.O=C(O)c1cc(C2CC2)c(OCC2CCN(S(=O)(=O)c3cc(Cl)c(Br)cc3F)CC2)cc1F                                                                                  '},
#   {'rs': 'C[C@H](NC(=O)c1cc(Cl)cnc1Oc1cccc(F)c1)c1ccc(C(=O)OC(C)(C)C)cc1                                                                                                  ',
#    'ps': 'C[C@H](NC(=O)c1cc(Cl)cnc1Cl)c1ccc(C(=O)OC(C)(C)C)cc1.Oc1cccc(F)c1                                                                                               '},
#   {'rs': 'c1ccc(Cn2ccc3ccccc32)cc1                                                                                                                                        ',
#    'ps': 'ClCc1ccccc1.c1ccc2[nH]ccc2c1                                                                                                                                    '},
#   {'rs': 'COc1ccc(CN(C(=O)OCc2ccccc2)[C@@H]2C(=O)N(Cc3ccc(OC)cc3OC)[C@@H]2CC=C(Br)Br)cc1                                                                                  ',
#    'ps': 'BrC(Br)(Br)Br.COc1ccc(CN(C(=O)OCc2ccccc2)[C@@H]2C(=O)N(Cc3ccc(OC)cc3OC)[C@@H]2CC=O)cc1                                                                          '},
#   {'rs': 'CCCCCC(O)c1ccc(Oc2ccc3ccccc3n2)cn1                                                                                                                              ',
#    'ps': 'CCCCCBr.O=Cc1ccc(Oc2ccc3ccccc3n2)cn1                                                                                                                            '},
#   {'rs': 'O=C1C[C@H](C(=O)Nc2cc(-c3cccc(COC(C(F)(F)F)C(F)(F)F)c3)n(-c3ccccc3)n2)CN1                                                                                       ',
#    'ps': 'Nc1cc(-c2cccc(COC(C(F)(F)F)C(F)(F)F)c2)n(-c2ccccc2)n1.O=C1C[C@H](C(=O)O)CN1                                                                                     '},
#   {'rs': 'CCS(=O)(=O)c1ccc(Cl)cc1CNC(=O)c1cc(Cl)c(CN2CCOC3(C2)CN(C(c2ccccc2)c2ccccc2)C3)c(C(F)(F)F)c1                                                                     ',
#    'ps': 'CCS(=O)(=O)c1ccc(Cl)cc1CNC(=O)c1cc(Cl)c(CBr)c(C(F)(F)F)c1.c1ccc(C(c2ccccc2)N2CC3(CNCCO3)C2)cc1                                                                  '},
#   {'rs': 'CCC(=O)N1CC[C@@H](NC(=O)c2c(C)[nH]c3c(-c4ccc(OC)cc4OCC4CC4)ncnc23)C1                                                                                            ',
#    'ps': 'CCC(=O)Cl.COc1ccc(-c2ncnc3c(C(=O)N[C@@H]4CCNC4)c(C)[nH]c23)c(OCC2CC2)c1                                                                                         '},
#   {'rs': 'COC(=O)c1cc(Br)cc(C(=O)N[C@H](C)c2ccccc2)c1                                                                                                                     ',
#    'ps': 'COC(=O)c1cc(Br)cc(C(=O)O)c1.C[C@@H](N)c1ccccc1                                                                                                                  '},
#   {'rs': 'Nc1ccc(C(=O)NCc2ccc(Oc3ccc(F)cc3)cc2)c(N)n1                                                                                                                     ',
#    'ps': 'NCc1ccc(Oc2ccc(F)cc2)cc1.Nc1ccc(C(=O)O)c(N)n1                                                                                                                   '},
#   {'rs': 'CC(=O)SCCC(=O)N1[C@H](C(=O)N2CCC[C@H]2C(=O)O)CS[C@@H]1c1ccccc1O                                                                                                 ',
#    'ps': 'CC(=O)SCCC(=O)N1[C@H](C(=O)O)CS[C@@H]1c1ccccc1O.O=C(O)[C@@H]1CCCN1                                                                                              '},
#   {'rs': 'NCCNc1ccnc2c1CC1(CN3CCC1CC3)O2                                                                                                                                  ',
#    'ps': 'Clc1ccnc2c1CC1(CN3CCC1CC3)O2.NCCN                                                                                                                               '},
#   {'rs': 'O=C(O)CCN1CCCC[C@H]1COc1ccc(Oc2ccc(Cl)cc2)cc1                                                                                                                   ',
#    'ps': 'COC(=O)CCN1CCCC[C@H]1COc1ccc(Oc2ccc(Cl)cc2)cc1                                                                                                                  '},
#   {'rs': 'COc1ccc(Oc2ncc(-c3cc(C(C)N)on3)s2)c(Cl)c1                                                                                                                       ',
#    'ps': 'COc1ccc(Oc2ncc(-c3cc(C(C)N4C(=O)c5ccccc5C4=O)on3)s2)c(Cl)c1                                                                                                     '},
#   {'rs': 'CSc1nc(-c2ccc(F)cc2C)c2ccc(=O)n(-c3c(F)cccc3F)c2n1                                                                                                              ',
#    'ps': 'CCOC(=O)/C=C/c1c(Nc2c(F)cccc2F)nc(SC)nc1-c1ccc(F)cc1C                                                                                                           '},
#   {'rs': 'COC(=O)c1ccc(CN2CCOCC2)c(OS(C)(=O)=O)c1                                                                                                                         ',
#    'ps': 'COC(=O)c1ccc(CN2CCOCC2)c(O)c1.CS(=O)(=O)Cl                                                                                                                      '},
#   {'rs': 'COC(=O)c1cc(C(=O)OC)cc(-c2cccc(Cl)c2)c1                                                                                                                         ',
#    'ps': 'COC(=O)c1cc(Br)cc(C(=O)OC)c1.OB(O)c1cccc(Cl)c1                                                                                                                  '},
#   {'rs': 'COC(=O)c1ccc(Nc2ccccc2)cc1                                                                                                                                      ',
#    'ps': 'COC(=O)c1ccc(Br)cc1.Nc1ccccc1                                                                                                                                   '},
#   {'rs': 'CCCCN(CCCC)c1ccc(C=Cc2ccc(CO)cc2)cc1                                                                                                                            ',
#    'ps': 'C1CCOC1.CCCCN(CCCC)c1ccc(C=O)cc1.[Li]c1ccccc1                                                                                                                   '},
#   {'rs': 'CCOC(=O)c1cc2cc(C(CC)(CC)c3ccc(OCC4(C(C)(C)C)OCCO4)c(C)c3)cc(C)c2o1                                                                                             ',
#    'ps': 'CCOC(=O)c1cc2cc(C(CC)(CC)c3ccc(OCC(=O)C(C)(C)C)c(C)c3)cc(C)c2o1.OCCO                                                                                            '},
#   {'rs': 'COc1cc[nH]c1/C=C1\\C(=O)Nc2ccc(NC(=O)Cc3cccs3)c(-c3ccc(C(=O)O)cc3)c21                                                                                            ',
#    'ps': 'COC(=O)c1ccc(-c2c(NC(=O)Cc3cccs3)ccc3c2/C(=C/c2[nH]ccc2OC)C(=O)N3)cc1                                                                                           '},
#   {'rs': 'CC(Oc1cc(-n2cnc3cnccc32)sc1C(N)=O)c1ccccc1Cl                                                                                                                    ',
#    'ps': 'COC(=O)c1sc(-n2cnc3cnccc32)cc1OC(C)c1ccccc1Cl.N                                                                                                                 '},
#   {'rs': 'O=C(Nc1cnc(Br)c(-c2ccc[n+]([O-])c2)n1)C1CC1                                                                                                                     ',
#    'ps': 'O=C(Nc1cnc(Br)c(-c2cccnc2)n1)C1CC1.O=C(OO)c1cccc(Cl)c1                                                                                                          '},
#   {'rs': 'CCOC(=O)c1c(C)[nH]c(C=C2C(=O)Nc3cccc(C4CCNCC4)c32)c1CCC(=O)O                                                                                                    ',
#    'ps': 'CCOC(=O)c1c(C)[nH]c(C=O)c1CCC(=O)O.O=C1Cc2c(cccc2C2CCNCC2)N1                                                                                                    '},
#   {'rs': 'CCOc1ccc2ccccc2c1-c1c[nH]c(N)n1                                                                                                                                 ',
#    'ps': 'CCOc1ccc2ccccc2c1-c1c[nH]c(NC(C)=O)n1                                                                                                                           '},
#   {'rs': 'CC(=O)N1CCN(c2ccc([N+](=O)[O-])c(C)c2)CC1                                                                                                                       ',
#    'ps': 'CC(=O)N1CCNCC1.Cc1cc(F)ccc1[N+](=O)[O-]                                                                                                                         '},
#   {'rs': 'CC(C)(C)OC(=O)N1CCCC(=O)CCC1                                                                                                                                    ',
#    'ps': 'CCOC(=O)C1CCN(C(=O)OC(C)(C)C)CCCC1=O                                                                                                                            '},
#   {'rs': 'COC(=O)c1cc(F)c(F)cc1Br                                                                                                                                         ',
#    'ps': 'C=[N+]=[N-].O=C(O)c1cc(F)c(F)cc1Br                                                                                                                              '},
#   {'rs': 'O=C(O)COc1ccc(F)c(NCc2c(F)ccc(-c3cccc(F)c3)c2F)c1F                                                                                                              ',
#    'ps': 'CCOC(=O)COc1ccc(F)c(NCc2c(F)ccc(-c3cccc(F)c3)c2F)c1F                                                                                                            '},
#   {'rs': 'COC(=O)C1SCCc2c(Br)cccc21                                                                                                                                       ',
#    'ps': 'COC(=O)C(Cl)SCCc1ccccc1Br                                                                                                                                       '},
#   {'rs': 'CC(C)(C)SCc1cc(NC(=O)C(C)(C)C)ccc1Cn1cc(CC#N)cn1                                                                                                                ',
#    'ps': 'CC(C)(C)SCc1cc(NC(=O)C(C)(C)C)ccc1CBr.N#CCc1cn[nH]c1                                                                                                            '},
#   {'rs': 'Cc1nn(-c2cccc(Cl)c2)c(C)c1C(=O)N1CCC(N2CCCC2)CC1                                                                                                                ',
#    'ps': 'C1CCN(C2CCNCC2)C1.Cc1nn(-c2cccc(Cl)c2)c(C)c1C(=O)O                                                                                                              '},
#   {'rs': 'COc1cccc2c1NC(CNC(C)=O)CO2                                                                                                                                      ',
#    'ps': 'CC(=O)OC(C)=O.COc1cccc2c1NC(CN)CO2                                                                                                                              '},
#   {'rs': 'CC(C)(C)OC(=O)N1CC=CC1                                                                                                                                          ',
#    'ps': 'C1=CCNC1.CC(C)(C)OC(=O)OC(=O)OC(C)(C)C                                                                                                                          '},
#   {'rs': 'CC(C)N1CCC(Oc2ccc(C3CCN(C(=O)c4ccc(F)cc4)CC3)cc2)CC1                                                                                                            ',
#    'ps': 'CC(C)N1CCC(Oc2ccc(C3CCNCC3)cc2)CC1.O=C(O)c1ccc(F)cc1                                                                                                            '},
#   {'rs': 'CN(c1cc(N2CCc3cc(S(C)(=O)=O)ccc32)ncn1)C1CCNCC1                                                                                                                 ',
#    'ps': 'CN(c1cc(N2CCc3cc(S(C)(=O)=O)ccc32)ncn1)C1CCN(Cc2ccccc2)CC1                                                                                                      '},
#   {'rs': 'CN(C(N)=O)c1n[nH]c2cc(-c3ccc(S(=O)(=O)N4CCC5(CC4)CN(C4CC4)C(=O)CO5)cc3)ccc12                                                                                    ',
#    'ps': 'CC1(C)OB(c2ccc(S(=O)(=O)N3CCC4(CC3)CN(C3CC3)C(=O)CO4)cc2)OC1(C)C.CN(C(N)=O)c1n[nH]c2cc(Br)ccc12                                                                 '},
#   {'rs': 'C[C@]1(F)CC(F)(F)[C@@](C)(c2cc(N)ccc2F)NC1=S                                                                                                                    ',
#    'ps': 'CC(C)(C)OC(=O)Nc1ccc(F)c([C@@]2(C)NC(=S)[C@@](C)(F)CC2(F)F)c1                                                                                                   '},
#   {'rs': 'CN(c1cc(NC(=O)OC(C)(C)C)c(NC(=O)CC(=O)c2cccc(-n3nncc3COC3CCCCO3)c2)cc1Cl)C1CC1                                                                                  ',
#    'ps': 'CC(C)(C)OC(=O)CC(=O)c1cccc(-n2nncc2COC2CCCCO2)c1.CN(c1cc(NC(=O)OC(C)(C)C)c(N)cc1Cl)C1CC1                                                                        '},
#   {'rs': 'CC(=O)N1[C@H](C(=O)NCC(=O)OCc2ccccc2)CC(=O)c2ccccc2N(Cc2ccccc2)C(=O)[C@H]1CC12CC3CC(CC(C3)C1)C2                                                                 ',
#    'ps': 'CC(=O)N1[C@H](C(=O)[O-])CC(=O)c2ccccc2N(Cc2ccccc2)C(=O)[C@H]1CC12CC3CC(CC(C3)C1)C2.NCC(=O)OCc1ccccc1                                                            '},
#   {'rs': 'COc1ccccc1-n1c(=O)c2cnc(S(C)=O)nc2n1C                                                                                                                           ',
#    'ps': 'COc1ccccc1-n1c(=O)c2cnc(SC)nc2n1C.O=C([O-])O                                                                                                                    '},
#   {'rs': 'Cc1cc(O)cc2c1C(CC(=O)OC(C)(C)C)OB2O                                                                                                                             ',
#    'ps': 'Cc1cc(OC2CCCCO2)cc2c1C(CC(=O)OC(C)(C)C)OB2O                                                                                                                     '},
#   {'rs': 'O=C1[C@H](CC[C@H](O)c2ccc(F)cc2)[C@@H](c2ccc(O)cc2)N1c1ccc(F)cc1                                                                                                ',
#    'ps': 'O=C1[C@H](CC[C@H](O)c2ccc(F)cc2)[C@@H](c2ccc(OCc3ccccc3)cc2)N1c1ccc(F)cc1                                                                                       '},
#   {'rs': 'NCCCC1CCCc2cc(S(=O)(=O)c3ccccc3)ccc21                                                                                                                           ',
#    'ps': 'N#CCCC1CCCc2cc(S(=O)(=O)c3ccccc3)ccc21                                                                                                                          '},
#   {'rs': 'C/C=C/c1cc(C(=O)O)c(F)cc1OCC12CC3CC(CC(C3)C1)C2                                                                                                                 ',
#    'ps': 'C/C=C/c1cc(C(=O)OC(C)(C)C)c(F)cc1OCC12CC3CC(CC(C3)C1)C2                                                                                                         '},
#   {'rs': 'Cc1ccc(N2CCN(C(=O)OC(C)(C)C)C[C@H]2C)c(C)c1                                                                                                                     ',
#    'ps': 'C[C@@H]1CN(C(=O)OC(C)(C)C)CCN1.Cc1ccc(Br)c(C)c1                                                                                                                 '},
#   {'rs': 'C#Cc1cc(Cl)ccc1F                                                                                                                                                ',
#    'ps': 'C[Si](C)(C)C#Cc1cc(Cl)ccc1F                                                                                                                                     '},
#   {'rs': 'Nc1c(C(=O)NCC(O)(CNC(=O)c2c(Cl)cccc2Cl)C(F)(F)F)cnn1-c1ccc(F)cc1                                                                                                ',
#    'ps': 'NCC(O)(CNC(=O)c1cnn(-c2ccc(F)cc2)c1N)C(F)(F)F.O=C(Cl)c1c(Cl)cccc1Cl                                                                                             '},
#   {'rs': 'CCN(CC)c1c([N+](=O)[O-])cc(C)c(N)c1[N+](=O)[O-]                                                                                                                 ',
#    'ps': 'CCN(CC)c1c([N+](=O)[O-])cc(C)c(Cl)c1[N+](=O)[O-].N                                                                                                              '},
#   {'rs': 'CN(Cc1cc(CO)ccc1Oc1ccc(Cl)c(Cl)c1)C(=O)OC(C)(C)C                                                                                                                ',
#    'ps': 'CN(Cc1cc(C=O)ccc1Oc1ccc(Cl)c(Cl)c1)C(=O)OC(C)(C)C                                                                                                               '},
#   {'rs': 'CC(=O)NC(C)CCc1ccc(Oc2ccc(OC(C)C)cn2)cc1                                                                                                                        ',
#    'ps': 'CC(=O)NC(C)CCc1ccc(Oc2ccc(O)cn2)cc1.CC(C)I                                                                                                                      '},
#   {'rs': 'CC1CCCN1CCc1nc2ccc(-c3cccnc3)cc2s1                                                                                                                              ',
#    'ps': 'CC1CCCN1CCc1nc2ccc(Br)cc2s1.OB(O)c1cccnc1                                                                                                                       '},
#   {'rs': 'COC(=O)Nc1ccc(-c2ccccc2C(F)(F)F)cc1                                                                                                                             ',
#    'ps': 'COC(=O)Cl.Nc1ccc(-c2ccccc2C(F)(F)F)cc1                                                                                                                          '},
#   {'rs': 'COc1cc(NC(=O)Cn2cnc3cccc([N+](=O)[O-])c32)cc(OCCN2CCCC2=O)c1                                                                                                    ',
#    'ps': 'COc1cc(N)cc(OCCN2CCCC2=O)c1.O=C(O)Cn1cnc2cccc([N+](=O)[O-])c21                                                                                                  '},
#   {'rs': 'C=Cc1cccc2c1CN(C(=O)O[C@@H]1C[C@@H](C(=O)OC)N(C(=O)OC(C)(C)C)C1)CC2                                                                                             ',
#    'ps': 'CN(C)C=O.COC(=O)[C@@H]1C[C@@H](OC(=O)N2CCc3cccc(OS(=O)(=O)C(F)(F)F)c3C2)CN1C(=O)OC(C)(C)C                                                                       '},
#   {'rs': 'CC(C)(C)OC(=O)N1CCN(c2ccncc2[N+](=O)[O-])CC1                                                                                                                    ',
#    'ps': 'CC(C)(C)OC(=O)N1CCNCC1.O=[N+]([O-])c1cnccc1Cl                                                                                                                   '},
#   {'rs': 'Cc1cc(Nc2nccc(C(F)(F)F)n2)cc(-c2ccc(CC(=O)N(C)C)nc2)c1                                                                                                          ',
#    'ps': 'CNC.Cc1cc(Nc2nccc(C(F)(F)F)n2)cc(-c2ccc(CC(=O)O)nc2)c1                                                                                                          '},
#   {'rs': 'CC(C)(C)OC(=O)N1CCC(N2CCNC(=O)C2)CC1                                                                                                                            ',
#    'ps': 'CC(C)(C)OC(=O)N1CCC(=O)CC1.O=C1CNCCN1                                                                                                                           '},
#   {'rs': 'CCOc1ccc(OCC(=O)O)c2c1C(=O)N(CSc1nnnn1-c1ccccc1)S2(=O)=O                                                                                                        ',
#    'ps': 'CCOc1ccc(OCC(=O)OC(C)(C)C)c2c1C(=O)N(CSc1nnnn1-c1ccccc1)S2(=O)=O                                                                                                '},
#   {'rs': 'CN(C)CCc1nnc(CN2C(=O)c3ccccc3C2=O)n1-c1ccccc1C(=O)c1ccccc1Cl                                                                                                    ',
#    'ps': 'CN(C)CCc1nnc(CO)n1-c1ccccc1C(=O)c1ccccc1Cl.O=C1NC(=O)c2ccccc21                                                                                                  '},
#   {'rs': 'OC/C=C/c1ccc(-n2cccn2)nc1                                                                                                                                       ',
#    'ps': 'O=C/C=C/c1ccc(-n2cccn2)nc1                                                                                                                                      '},
#   {'rs': 'CC1CCCN1CC(C)N1c2ccccc2Sc2ccc(C#N)cc21                                                                                                                          ',
#    'ps': 'CC(COS(C)(=O)=O)N1c2ccccc2Sc2ccc(C#N)cc21.CC1CCCN1                                                                                                              '},
#   {'rs': 'CCOC(=O)c1nn(-c2ccccc2Cl)c(Br)c1CNC(C)C                                                                                                                         ',
#    'ps': 'CC(C)N.CCOC(=O)c1nn(-c2ccccc2Cl)c(Br)c1C=O                                                                                                                      '},
#   {'rs': 'O=C(NNc1cnc2ccc(Br)cc2n1)C1CC1                                                                                                                                  ',
#    'ps': 'NNc1cnc2ccc(Br)cc2n1.O=C(O)C1CC1                                                                                                                                '},
#   {'rs': 'CC(C)(C)OC(=O)NCCCOc1cc(O)cc(C(=O)O)c1                                                                                                                          ',
#    'ps': 'COC(=O)c1cc(O)cc(OCCCNC(=O)OC(C)(C)C)c1                                                                                                                         '},
#   {'rs': 'CN1c2cc(-c3cccc(F)c3C#N)ccc2N(CC2CC2)S1(=O)=O                                                                                                                   ',
#    'ps': 'CN1c2cc(B3OC(C)(C)C(C)(C)O3)ccc2N(CC2CC2)S1(=O)=O.N#Cc1c(F)cccc1Br                                                                                              '},
#   {'rs': 'CCCC(=O)Nc1ccc(C=CCN2CCC(=C3c4ccccc4C=Cc4ccccc43)CC2)cc1                                                                                                        ',
#    'ps': 'CCCC(=O)O.Nc1ccc(C=CCN2CCC(=C3c4ccccc4C=Cc4ccccc43)CC2)cc1                                                                                                      '},
#   {'rs': 'COc1cc(F)ccc1C(=O)NC1COCCn2c1nc(-c1ccncc1)cc2=O                                                                                                                 ',
#    'ps': 'COc1cc(F)ccc1C(=O)O.NC1COCCn2c1nc(-c1ccncc1)cc2=O                                                                                                               '},
#   {'rs': 'CCN1C(=O)CCCc2c1ccc(Nc1ncc(Cl)c(Nc3ccccc3-n3cccn3)n1)c2OC                                                                                                       ',
#    'ps': 'CCN1C(=O)CCCc2c1ccc(N)c2OC.Clc1ncc(Cl)c(Nc2ccccc2-n2cccn2)n1                                                                                                    '},
#   {'rs': 'Cc1ccc(-c2noc(N3CCC3)n2)cc1[N+](=O)[O-]                                                                                                                         ',
#    'ps': 'C1CNC1.Cc1ccc(-c2noc(Cl)n2)cc1[N+](=O)[O-]                                                                                                                      '},
#   {'rs': 'N#Cc1cc(COc2ccc3c(c2)cc2n3CCC2CC(=O)O)cc(OC(F)(F)F)c1                                                                                                           ',
#    'ps': 'CC(C)(C)OC(=O)CC1CCn2c1cc1cc(OCc3cc(C#N)cc(OC(F)(F)F)c3)ccc12                                                                                                   '},
#   {'rs': 'NCCCCN1CCC(Cc2nc3ccccc3n2Cc2ccco2)CC1                                                                                                                           ',
#    'ps': 'N#CCCCN1CCC(Cc2nc3ccccc3n2Cc2ccco2)CC1                                                                                                                          '},
#   {'rs': 'CS(=O)(=O)c1ccc(Cn2c(=O)c(C(=O)NCCN3CCCC3)c(O)c3ncc(Cc4ccccc4)cc32)cc1                                                                                          ',
#    'ps': 'CCOC(=O)c1c(O)c2ncc(Cc3ccccc3)cc2n(Cc2ccc(S(C)(=O)=O)cc2)c1=O.NCCN1CCCC1                                                                                        '},
#   {'rs': 'COc1nc(Cc2cccc(Br)c2NS(=O)(=O)C(F)F)nc(OC)n1                                                                                                                    ',
#    'ps': 'COc1nc(Cc2cccc(Br)c2N)nc(OC)n1.O=S(=O)(Cl)C(F)F                                                                                                                 '},
#   {'rs': 'C/C(=N\\N1CCNC1=O)c1cnc2nnn(Cc3ccc4ncccc4c3)c2n1                                                                                                                 ',
#    'ps': 'CC(=O)c1cnc2nnn(Cc3ccc4ncccc4c3)c2n1.NN1CCNC1=O                                                                                                                 '},
#   {'rs': 'COc1ccc2c(c1)C(C)(C)C(=NO)CC2                                                                                                                                   ',
#    'ps': 'COc1ccc2c(c1)C(C)(C)C(=O)CC2.NO                                                                                                                                 '},
#   {'rs': 'CCCCOc1nc(N)c2nc(OC)n(CCCC3CCCN(C(=O)OCc4ccccc4)C3)c2n1                                                                                                         ',
#    'ps': 'CCCCOc1nc(N)c2nc(OC)n(CCCC3CCCCN3C(=O)OCc3ccccc3)c2n1                                                                                                           '},
#   {'rs': 'OCCOc1cccc(OCc2ccccc2)c1                                                                                                                                        ',
#    'ps': 'BrCc1ccccc1.OCCOc1cccc(O)c1                                                                                                                                     '},
#   {'rs': 'CC(C)(C)OC(=O)N[C@@H]1C[C@H]1c1cccc(C(=O)O)c1                                                                                                                   ',
#    'ps': 'COC(=O)c1cccc([C@@H]2C[C@H]2NC(=O)OC(C)(C)C)c1                                                                                                                  '},
#   {'rs': 'CC(C)(C)OC(=O)N1CCN(c2cccc(Br)n2)CC(O)C1                                                                                                                        ',
#    'ps': 'CC(C)(C)OC(=O)OC(=O)OC(C)(C)C.OC1CNCCN(c2cccc(Br)n2)C1                                                                                                          '},
#   {'rs': 'CC(C)N1CCn2c(Cc3cccc(Cl)c3Cl)nc(=O)c(O)c2C1=O                                                                                                                   ',
#    'ps': 'CC(C)N1CCn2c(Cc3cccc(Cl)c3Cl)nc(=O)c(OCc3ccccc3)c2C1=O                                                                                                          '},
#   {'rs': 'COc1cc2nccc(Oc3ccc(NC(=O)Nc4ccccc4)cc3)c2cc1CN                                                                                                                  ',
#    'ps': 'COc1cc2nccc(Oc3ccc(NC(=O)Nc4ccccc4)cc3)c2cc1C#N                                                                                                                 '},
#   {'rs': 'Cc1ccc2nc(N3CCS(=O)(=O)c4cc(Oc5ccccc5)ccc4C3)cc(Cl)c2c1                                                                                                         ',
#    'ps': 'Cc1ccc2nc(N3CCS(=O)(=O)c4cc(O)ccc4C3)cc(Cl)c2c1.Ic1ccccc1                                                                                                       '},
#   {'rs': 'COC(=O)C(Cc1ccc(C(F)(F)P(=O)(OC(C)(C)C)OC(C)(C)C)cc1)(Cc1ccc(C(F)(F)P(=O)(OC(C)(C)C)OC(C)(C)C)cc1)C(=O)O                                                        ',
#    'ps': 'COC(=O)C(Cc1ccc(C(F)(F)P(=O)(OC(C)(C)C)OC(C)(C)C)cc1)(Cc1ccc(C(F)(F)P(=O)(OC(C)(C)C)OC(C)(C)C)cc1)C(=O)OCc1ccccc1                                               '},
#   {'rs': 'CCOC(=O)COc1cccc(-c2noc(-c3ccc(OC(C)C)c(C#N)c3)n2)c1CC                                                                                                          ',
#    'ps': 'CCOC(=O)CBr.CCc1c(O)cccc1-c1noc(-c2ccc(OC(C)C)c(C#N)c2)n1                                                                                                       '},
#   {'rs': 'C=CC(=O)C[C@H]1C[C@H](c2ccc(OC)cc2)[C@@H](OCc2ccc3c(c2)N(CCCOC)CCO3)CN1S(=O)(=O)c1ccc(C)cc1                                                                     ',
#    'ps': 'C=C[Mg+].COCCCN1CCOc2ccc(CO[C@H]3CN(S(=O)(=O)c4ccc(C)cc4)[C@@H](CC(=O)N(C)OC)C[C@@H]3c3ccc(OC)cc3)cc21                                                          '},
#   {'rs': 'CN(C)CCNC(=O)Cc1ccc(OCc2ccc(-c3ccccc3)cc2)cc1                                                                                                                   ',
#    'ps': 'CN(C)CCN.COC(=O)Cc1ccc(OCc2ccc(-c3ccccc3)cc2)cc1                                                                                                                '},
#   {'rs': 'NC(=O)[C@H](CC1CC1)NC(=O)c1ccc(N2CC(F)(F)C2)c(OCC2CC2)n1                                                                                                        ',
#    'ps': 'NC(=O)[C@@H](N)CC1CC1.O=C(O)c1ccc(N2CC(F)(F)C2)c(OCC2CC2)n1                                                                                                     '},
#   {'rs': 'COc1cc(C)c2c(c1-c1ccc([C@@H](C)CNC(=O)OC(C)(C)C)cc1)c1cc(C)sc1c(=O)n2COCC[Si](C)(C)C                                                                            ',
#    'ps': 'COc1cc(C)c2c(c1Br)c1cc(C)sc1c(=O)n2COCC[Si](C)(C)C.C[C@@H](CNC(=O)OC(C)(C)C)c1ccc(B2OC(C)(C)C(C)(C)O2)cc1                                                       '},
#   {'rs': 'Cc1cc(CO)c2cccc(OCc3ccccc3)c2n1                                                                                                                                 ',
#    'ps': 'Cc1cc(C=O)c2cccc(OCc3ccccc3)c2n1                                                                                                                                '},
#   {'rs': 'Cc1ccc(C#N)c[n+]1[O-]                                                                                                                                           ',
#    'ps': 'Cc1ccc(C#N)cn1.O=C(OO)c1cccc(Cl)c1                                                                                                                              '},
#   {'rs': 'N[C@@H]1CCC[C@H](CO)C1                                                                                                                                          ',
#    'ps': 'N[C@@H]1CCC[C@H](C(=O)O)C1                                                                                                                                      '},
#   {'rs': 'CC(C)(C)OC(=O)N1CCN(c2ccccc2OC2CCCN(C(=O)c3ccccc3)C2)CC1                                                                                                        ',
#    'ps': 'CC(C)(C)OC(=O)N1CCN(c2ccccc2OC2CCCNC2)CC1.O=C(Cl)c1ccccc1                                                                                                       '},
#   {'rs': 'CCOC(=O)N1c2ccc(OC)nc2[C@H](NC(=O)O[C@@H](C)c2ccccc2)C[C@@H]1CC                                                                                                 ',
#    'ps': 'CCOC(=O)Cl.CC[C@H]1C[C@@H](NC(=O)O[C@@H](C)c2ccccc2)c2nc(OC)ccc2N1                                                                                              '},
#   {'rs': 'Cc1csc(N2C(=O)C(Cc3ccccc3)NC2=S)n1                                                                                                                              ',
#    'ps': 'COC(=O)C(Cc1ccccc1)NC(=S)Nc1nc(C)cs1                                                                                                                            '},
#   {'rs': 'COc1cc(C2(O)C(=O)N(C(c3ccccc3)c3ccccc3)c3ccccc32)c(O)cn1                                                                                                        ',
#    'ps': 'COCOc1cnc(OC)cc1C1(O)C(=O)N(C(c2ccccc2)c2ccccc2)c2ccccc21                                                                                                       '},
#   {'rs': 'N#Cc1ccc(CN=[N+]=[N-])s1                                                                                                                                        ',
#    'ps': 'N#Cc1ccc(CBr)s1.[N-]=[N+]=[N-]                                                                                                                                  '},
#   {'rs': 'CN(C)C1(c2cccs2)CCN(CCN)CC1                                                                                                                                     ',
#    'ps': 'CN(C)C1(c2cccs2)CCN(CCNC(=O)OC(C)(C)C)CC1                                                                                                                       '},
#   {'rs': 'COC(=O)C1(C)CCNCC1                                                                                                                                              ',
#    'ps': 'COC(=O)C1(C)CCN(C(=O)OC(C)(C)C)CC1                                                                                                                              '},
#   {'rs': 'O=C(O)c1cnc(N2CCOCC2)cc1Oc1ccccc1                                                                                                                               ',
#    'ps': 'CCOC(=O)c1cnc(N2CCOCC2)cc1Oc1ccccc1                                                                                                                             '},
#   {'rs': 'CCOC(=O)CCc1ccc(O)c(C)c1C(F)(F)F                                                                                                                                ',
#    'ps': 'CCOC(=O)CCc1ccc(OC)c(C)c1C(F)(F)F                                                                                                                               '},
#   {'rs': 'O=C(c1ccc(Cl)cc1)N1CC(O)C(N2CCN(Cc3ccc(Cl)cc3)CC2)C1                                                                                                            ',
#    'ps': 'O=C(c1ccc(Cl)cc1)N1CC(O)C(N2CCNCC2)C1.O=Cc1ccc(Cl)cc1                                                                                                           '},
#   {'rs': 'COc1cc2ncnc(N3CCN(C(=O)N(c4ccccc4)c4ccccc4)CC3)c2cc1OC                                                                                                          ',
#    'ps': 'COc1cc2ncnc(N3CCNCC3)c2cc1OC.O=C(Cl)N(c1ccccc1)c1ccccc1                                                                                                         '},
#   {'rs': 'O=C(O)[C@@H]1CC(=O)N1Cc1ccccc1                                                                                                                                  ',
#    'ps': 'O=C(OCc1ccccc1)[C@@H]1CC(=O)N1Cc1ccccc1                                                                                                                         '},
#   {'rs': 'CCOC(=O)CNC(=O)[C@@H]1CS[C@H](c2ccccc2O)N1C(=O)CCSC(=O)c1ccccc1                                                                                                 ',
#    'ps': 'CCOC(=O)CN.O=C(SCCC(=O)N1[C@H](C(=O)O)CS[C@@H]1c1ccccc1O)c1ccccc1                                                                                               '},
#   {'rs': 'CSc1ccc(CN2CCC(=O)C(C(c3ccccc3)c3ccccc3)C2)cc1                                                                                                                  ',
#    'ps': 'CSc1ccc(CO)cc1.O=C1CCNCC1C(c1ccccc1)c1ccccc1                                                                                                                    '},
#   {'rs': 'CC(C)c1noc(N2CCC(COc3ccc(-c4ccc(S(=O)(=O)NCCO)cc4)cc3)CC2)n1                                                                                                    ',
#    'ps': 'CC(C)c1noc(N2CCC(COc3ccc(Br)cc3)CC2)n1.O=S(=O)(NCCO)c1ccc(B(O)O)cc1                                                                                             '},
#   {'rs': 'O=C(C=Cc1cccnc1)Nc1ccc(S(=O)(=O)c2cccc(OC(F)(F)F)c2)cc1                                                                                                         ',
#    'ps': 'Nc1ccc(S(=O)(=O)c2cccc(OC(F)(F)F)c2)cc1.O=C(Cl)C=Cc1cccnc1                                                                                                      '},
#   {'rs': 'Cc1nc(C(=O)N2CCC[C@@H](Nc3ncc(Br)cn3)C2)c(-c2ccc(C)c(C)c2)s1                                                                                                    ',
#    'ps': 'Brc1cnc(N[C@@H]2CCCNC2)nc1.Cc1nc(C(=O)O)c(-c2ccc(C)c(C)c2)s1                                                                                                    '},
#   {'rs': 'CCOC(=O)CC1CCC(c2ncc(-c3ccc(NC(=O)c4nc(-c5ccccc5)oc4C)cc3)s2)CC1                                                                                                ',
#    'ps': 'CCOC(=O)CC1CCC(c2ncc(-c3ccc(NC(=O)c4nc(-c5ccccc5)oc4C(F)(F)F)cc3)s2)CC1                                                                                         '},
#   {'rs': 'CCC1=C(C(=O)OCc2ccccc2)C(c2ccc(F)cc2F)N(C(=O)Oc2ccc([N+](=O)[O-])cc2)C(OC)=N1                                                                                   ',
#    'ps': 'CCC1=C(C(=O)OCc2ccccc2)C(c2ccc(F)cc2F)NC(OC)=N1.O=C(Cl)Oc1ccc([N+](=O)[O-])cc1                                                                                  '},
#   {'rs': 'COc1cc(OC)cc(C(=CC#N)c2ccc(O)c(OC)c2)c1                                                                                                                         ',
#    'ps': 'COc1cc(OC)cc(C(=CC#N)c2ccc(O[Si](C)(C)C(C)(C)C)c(OC)c2)c1                                                                                                       '},
#   {'rs': 'CC(C)(C)OC(=O)Cn1cnc(-c2ccc(N)cc2)c1                                                                                                                            ',
#    'ps': 'CC(C)(C)OC(=O)Cn1cnc(-c2ccc([N+](=O)[O-])cc2)c1                                                                                                                 '},
#   {'rs': 'COc1cc(N2CCN(C(C)C)CC2)c(F)cc1N                                                                                                                                 ',
#    'ps': 'COc1cc(N2CCN(C(C)C)CC2)c(F)cc1[N+](=O)[O-]                                                                                                                      '},
#   {'rs': 'O=C(O)NCc1cccc(-c2ccoc2)c1                                                                                                                                      ',
#    'ps': 'CC1(C)OB(c2ccoc2)OC1(C)C.O=C(O)NCc1cccc(Br)c1                                                                                                                   '},
#   {'rs': 'Cc1ccnc(C(=O)c2cn(-c3cccc(-c4cccnc4F)c3)cn2)c1                                                                                                                  ',
#    'ps': 'CON(C)C(=O)c1cn(-c2cccc(-c3cccnc3F)c2)cn1.Cc1ccnc(Br)c1                                                                                                         '},
#   {'rs': 'COc1ncc(Cl)nc1NS(=O)(=O)c1cccc(Cl)c1Cl                                                                                                                          ',
#    'ps': 'COc1ncc(Cl)nc1N.O=S(=O)(Cl)c1cccc(Cl)c1Cl                                                                                                                       '},
#   {'rs': 'COc1ccc(-c2cc(NC(=O)c3ccccc3C)on2)cc1                                                                                                                           ',
#    'ps': 'COc1ccc(-c2cc(N)on2)cc1.Cc1ccccc1C(=O)Cl                                                                                                                        '},
#   {'rs': 'COC(=O)CCCCCCNC(=O)C(=O)c1cn2c3c(cccc13)CCC2                                                                                                                    ',
#    'ps': 'COC(=O)CCCCCCN.O=C(O)C(=O)c1cn2c3c(cccc13)CCC2                                                                                                                  '},
#   {'rs': 'COc1ccccc1-c1ccc(C=O)s1                                                                                                                                         ',
#   {'rs': 'O=C(O)Cc1c(-c2ccc(Cl)c(S(=O)(=O)NC3CCCCC3)c2)[nH]c2ccccc12                                                                                                      ',
#    'ps': 'NNc1ccccc1.O=C(O)CCC(=O)c1ccc(Cl)c(S(=O)(=O)NC2CCCCC2)c1                                                                                                        '},
#   {'rs': 'C=C[C@@H](C#CC#C[C@@H](CCCCCCCCC)NC(=O)c1ccccc1)OC(C)=O                                                                                                         ',
#    'ps': 'C=C[C@@H](C#CC#C[C@H](N)CCCCCCCCC)OC(C)=O.O=C(OC(=O)c1ccccc1)c1ccccc1                                                                                           '},
#   {'rs': 'CCCCCC(CCCCC)CCCCCCCCN(C)C                                                                                                                                      ',
#    'ps': 'CCCCCC(=CCCCCCCCN(C)C)CCCCC                                                                                                                                     '},
#   {'rs': 'OC1CCN(c2cccc(-c3ccnc(Cl)n3)c2)CC1                                                                                                                              ',
#    'ps': 'O=C1CCN(c2cccc(-c3ccnc(Cl)n3)c2)CC1                                                                                                                             '},
#   {'rs': 'c1cnc2c(c1)-c1cccnc1C2                                                                                                                                          ',
#    'ps': 'O=C1c2ncccc2-c2cccnc21                                                                                                                                          '},
#   {'rs': 'CCOc1nnc(Cl)c(C)c1C                                                                                                                                             ',
#    'ps': 'CCO.Cc1c(Cl)nnc(Cl)c1C                                                                                                                                          '},
#   {'rs': 'Cc1ccc(-n2nc(C)c3c(C(=O)Nc4c(C)ccnc4C)cc(C)nc32)cn1                                                                                                             ',
#    'ps': 'Cc1ccc(-n2nc(C)c3c(C(=O)O)cc(C)nc32)cn1.Cc1ccnc(C)c1N                                                                                                           '},
#   {'rs': 'COC(=O)c1ccc(-c2ccc(N)nc2)cc1                                                                                                                                   ',
#    'ps': 'Nc1ccc(-c2ccc(C(=O)O)cc2)cn1.O=C([O-])O                                                                                                                         '},
#   {'rs': 'Brc1cc(-c2cccc(-c3cccc4c3sc3ccccc34)c2)cc([Si](c2ccccc2)(c2ccccc2)c2ccccc2)c1                                                                                   ',
#    'ps': 'Brc1cc(Br)cc([Si](c2ccccc2)(c2ccccc2)c2ccccc2)c1.CC1(C)OB(c2cccc(-c3cccc4c3sc3ccccc34)c2)OC1(C)C                                                                '},
#   {'rs': 'O=C(O)c1cccc2c(=O)c3ccccc3oc12                                                                                                                                  ',
#    'ps': 'COC(=O)c1cccc2c(=O)c3ccccc3oc12                                                                                                                                 '},
#   {'rs': 'CCOc1cc(CN2CCCC2)ccc1N                                                                                                                                          ',
#    'ps': 'CCOc1cc(C(=O)N2CCCC2)ccc1N                                                                                                                                      '},
#   {'rs': 'CCCn1nc2c(N)nc3ccccc3c2c1CC(C)(C)NC(=O)c1cccnc1                                                                                                                 ',
#    'ps': 'CCCn1nc2c(N)nc3ccccc3c2c1CC(C)(C)N.O=C(Cl)c1cccnc1                                                                                                              '},
#   {'rs': 'COC(=O)C(CN)(C(=O)OC)N1CCN(C(=O)OC(C)(C)C)CC1                                                                                                                   ',
#    'ps': 'COC(=O)C(CN1C(=O)c2ccccc2C1=O)(C(=O)OC)N1CCN(C(=O)OC(C)(C)C)CC1                                                                                                 '},
#    'ps': 'CCS(=O)(=O)Nc1nc2c(I)cc(-c3c(C)noc3C)cc2[nH]1.Cc1ccc2ncccc2c1B(O)O                                                                                              '},
#   {'rs': 'CC(C)Oc1ccc(C=O)cc1Br                                                                                                                                           ',
#    'ps': 'CC(C)Br.O=Cc1ccc(O)c(Br)c1                                                                                                                                      '},
#   {'rs': 'CCCCCCCCCOC(=O)c1cc(-c2csc(-c3ccc(OCC)c(OCC)c3)n2)ccc1OCOC                                                                                                      ',
#    'ps': 'CCCCCCCCCBr.CCOc1ccc(-c2nc(-c3ccc(OCOC)c(C(=O)O)c3)cs2)cc1OCC                                                                                                   '},
#   ...]}

# %%
for key in data.keys(): print(key + " " + str(len(data[key])))

# %%
len(" ^#%()+-./0123456789=@ABCDEFGHIKLMNOPRSTVXYZ[\\]abcdefgilmnoprstuy$")

# %%
data["train"][10]

# %%
F.one_hot(data["train"][100]["rs"].to(device, dtype=torch.int64), num_classes=len(chars))

# %%
# Define ReactionDataset Class
# How to shuffle each epoch? Check later.


from torch.utils.data import Dataset
import torch.nn.functional as F

class ReactionDataset(Dataset):

    def __init__(self, data, split, rep=" ^#%()+-./0123456789=@ABCDEFGHIKLMNOPRSTVXYZ[\\]abcdefgilmnoprstuy$"):
        self.split = split
        self.data = data[self.split]
        self.rep = rep
        # Add augmentation methods here later
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, index):
        rs_smiles = self.data[index]["rs"]
        ps_smiles = self.data[index]["ps"]
        
        # Augment smiles here for train
        
        rs = 
        
        return {
            'rs': F.one_hot(self.data[index]["rs"].to(dtype=torch.int64), num_classes=len(self.rep)),
            'ps':  F.one_hot(self.data[index]["ps"].to(dtype=torch.int64), num_classes=len(self.rep))
        }

# %%
from torch.utils.data import DataLoader

datasets = {}
dataloaders = {}
for split in ['train', 'valid', 'test']:
    datasets[split] = ReactionDataset(data=data,
                                   split=split)

    dataloaders[split] = DataLoader(datasets[split],
                                    batch_size=32,
                                    shuffle=(split != 'test'),
                                    num_workers=4,
                                    pin_memory=False)# Was True before.

# %%
element = datasets["train"].__getitem__(index=100)
element["rs"].shape

# %%
encoder_layer = nn.TransformerEncoderLayer(d_model=512, nhead=8)
transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=6)
src = torch.rand(10, 64, 512)
out = transformer_encoder(src)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_16266/962022010.py in <module>
# ----> 1 encoder_layer = nn.TransformerEncoderLayer(d_model=512, nhead=8)
#       2 transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=6)
#       3 src = torch.rand(10, 64, 512)
#       4 out = transformer_encoder(src)
#
# NameError: name 'nn' is not defined

# %%
from ...constants import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_16266/3605945618.py in <module>
# ----> 1 from ...constants import *
#
# ImportError: attempted relative import with no known parent package

# %%
with open("/home/arvid/data/USTPO_paper_5x/patents40k_x5MSShuf.csv") as f:
    lines = f.readlines()

# %%
lines = lines[1:]
ix = np.arange(0,4000)
print(ix)
np.random.shuffle(ix)
print(ix)
ix = np.repeat(ix*10,10)
print(ix)
ix += np.tile(np.arange(0,10),4000)
print(ix)
split_ix = int((.75*40000)-(.75*40000)%10)
print(split_ix)
#data = {"train", "eval"}
#for line in lines[1:]:
#train = [lines[e] for e in ix[:split_ix]]
#eval = [lines[e] for e in ix[split_ix:]]
print((eval))
print((train))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
